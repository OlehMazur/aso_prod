# %%
# %run sc_aso.py Пятёрочка Москва 001 0 34
# Out:
# Optimization of the assortment given a choice model
# Opening choice model, format GDT
#
# Date: 2018-12-13
# Network: Пятёрочка
# City: Москва
# transaction file:  transaction_data_Пятёрочка_Москва_001.dat with nb_prod = 63 products
#
# min_capacity:  0
# max_capacity:  34
#
# 1859 assortments available in transaction dataset
#
# Optimal assortment found in 125.06269645690918 seconds. Number of products 35 .Products present in optimal assortment:
#
# [6500, 6978, 7019, 7020, 7029, 7041, 7042, 6056, 7043, 7045, 7046, 7054, 7056, 7057, 7058, 7223, 6204, 7239, 7240, 7281, 7349, 7359, 7361, 7436, 7464, 7468, 7475, 7477, 7547, 7571, 7633, 6235, 7672, 7679, 6255]
#
# ...
